# %% [markdown]
# This notebook loads and saves the sentiment/sst2-adapter (https://adapterhub.ml/adapters/ukp/roberta-base-sst_pfeiffer/, (RoBERTa-base) for Sentiment Analysis.
#
# The loadings of pre-trained adapters is done according to: https://colab.research.google.com/github/Adapter-Hub/adapter-transformers/blob/master/notebooks/02_Adapter_Inference.ipynb#scrollTo=Khgmm6OQvvku).

# %%
# !pip install -U git+https://github.com/Adapter-Hub/adapter-transformers.git
# !pip install datasets
# Out:
# ...
#   Cloning https://github.com/Adapter-Hub/adapter-transformers.git to /tmp/pip-req-build-wi6_nkb7
#   Running command git clone -q https://github.com/Adapter-Hub/adapter-transformers.git /tmp/pip-req-build-wi6_nkb7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 3.3 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 52.5 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#   Created wheel for adapter-transformers: filename=adapter_transformers-2.1.2-py3-none-any.whl size=2539220 sha256=07f8d7b9a8995ef920950e42af3bfdc9c5fe4e0fedeeb4224e1573c95184a2ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nev6im_y/wheels/60/0e/d5/86e64fef3085f149b504f48af9ca6e8f6da427f42da9b4bbe5
# Successfully built adapter-transformers
# ...
#      |████████████████████████████████| 264 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 118 kB 56.0 MB/s
# ...

# %% [markdown]
# https://adapterhub.ml/explore/sentiment/sst-2/

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import sys
path = "/content/gdrive/MyDrive/master_hpi/NLP_Project/code/"
sys.path.append(path)

# %%
from transformers import AutoModelWithHeads, AdapterConfig

model = AutoModelWithHeads.from_pretrained("roberta-base")
config = AdapterConfig.load("pfeiffer")
model.load_adapter("sentiment/sst-2@ukp", config=config)
print(model.config.adapters.adapters)
model.set_active_adapters("sst_glue")

#model.train_adapter("sst_glue")
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModelWithHeads: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModelWithHeads from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModelWithHeads from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.save_adapter(path +"models/robertasstpretrained/", "sst_glue")
